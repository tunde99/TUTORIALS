# %% [markdown]
# ---
# ---
# ![masakhane.io.png](data:image/png;base64,...)

# %% [markdown]
# **Author**: [Tunde Ajayi](https://tundeajayi.github.io)

# %% [markdown]
# # Quick Python Review

# %% [markdown]
# ---

# %% [markdown]
# #### 1. What is the square root of 4096, without the use of built-in function ?

# %%
# Type your code here --> 64
square_root = int(4096 ** (1/2))
print(square_root)
# Out:
# 64

# %%
# Chiamaka's code
import math 
print(int(math.sqrt(4096)))
# Out:
# 64

# %%
# Aremu's contribution
sqrt_num = int(math.sqrt(4096))
print(sqrt_num)
# Out:
# 64

# %% [markdown]
# #### 2. Split the following string into individual words in a list.
# ```
# sentence = 'This is called tokenisation in NLP!'
# ```

# %%
# Type your code here
sentence = 'This is called tokenisation in NLP!'

# Shamsudeen's code
split_str = sentence.split()
print(split_str)
# Out:
# ['This', 'is', 'called', 'tokenisation', 'in', 'NLP!']

# %% [markdown]
# ---

# %% [markdown]
# #### 3. How can you split the sentence in question 2. above without the exclamation mark at the end of the sentence ?

# %%
# Type your code here
sentence_without_exclamation = sentence.rstrip("!").split()
print(sentence_without_exclamation)
# Out:
# ['This', 'is', 'called', 'tokenisation', 'in', 'NLP']

# %% [markdown]
# ---

# %% [markdown]
# #### 4. Use the following information to display the text as shown below:
# ```
# community = 'Masakhane'
# vision = 'representation and coverage of low resource language'
# ```
# *Output*:
# ```
# 'Masakhane was created with the aim of improving the representation and coverage of low resource language'
# ```

# %%
# Type your code here
community = 'Masakhane'
vision = 'representation and coverage of low resource language'

# Vishakha's code
result = community + " was created with the aim of improving the " + vision 
print(result)
# Out:
# Masakhane was created with the aim of improving the representation and coverage of low resource language

# %%
#f-string formatting - another alternative way of displaying strings
print(f'{community} was created with the aim of improving the {vision}')
# Out:
# Masakhane was created with the aim of improving the representation and coverage of low resource language

# %% [markdown]
# ---

# %% [markdown]
# #### 5. Using indexing, extract the word 'hello' from the dictionary below:
# ```
# d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}
# ```

# %%
# Type your code here

# Vishakha's code
d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}
d['k1'][3]['tricky'][3]['target'][3]
# Out:
# 'hello'

# %%
# Espoir's code
d.get('k1')[3]['tricky'][3]['target'][3]
# Out:
# 'hello'

# %% [markdown]
# ---

# %% [markdown]
# #### 6. A list is different from a tuple. What is their major difference ?

# %%
# Type your answer here
immutable - tuple
mutable - list

# %% [markdown]
# ---

# %% [markdown]
# #### 7. Given an email address i.e. tunde@masakhane.com, write a function that will return the username, domain and the extension.
#
# *Hint:*
# ```
# username:  tunde
# domain:    masakhane
# extension: com
# ```

# %%
# Type your code here

# %% [markdown]
# ---

# %% [markdown]
# #### 8. Write a function to check if the word 'dog' exists in a given input string (test for string1 and string 2).
#
# Note that 'dog' is not equal to 'DOG'.
#
# ```
# string1 = 'What type of dog do you have at home?'
# string2 = 'what type of DOG do you have at home?'
# ```

# %%
# Type your code here

# %% [markdown]
# What will you do to ```string2``` to make it yield same output as ```string1```?

# %%
# Type your code here

# %% [markdown]
# How many characters are in string1 ?

# %%
# Type your code here

# %% [markdown]
# ---

# %% [markdown]
# #### 9. Define a sum_of_values_and_indices function that accepts a list of numbers. It should return the sum of all of the elements along with their index values.
#
# ```
# EXAMPLES
#
# sum_of_values_and_indices([1, 2, 3])    => (1 + 0) + (2 + 1) + (3 + 2) => 9
#
# sum_of_values_and_indices([0, 0, 0, 0]) => 6
#
# sum_of_values_and_indices([])           => 0
# ```

# %%
# Type your code here

# %% [markdown]
# ---
# # The End!!!
# ---
