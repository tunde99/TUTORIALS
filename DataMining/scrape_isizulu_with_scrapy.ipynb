# %% [markdown]
# # Get isulu url content
# https://www.isolezwe.co.za/

# %%
# Install dependency
# !pip install scrapy
# Out:
# Collecting scrapy
#   Downloading https://files.pythonhosted.org/packages/95/68/0e84466f83ed7d57b0da402bef1bb33a030224a64523a744de2abb8595f4/Scrapy-2.5.0-py2.py3-none-any.whl (254kB)
#      |████████████████████████████████| 256kB 4.3MB/s
# Collecting protego>=0.1.15
#   Downloading https://files.pythonhosted.org/packages/db/6e/bf6d5e4d7cf233b785719aaec2c38f027b9c2ed980a0015ec1a1cced4893/Protego-0.1.16.tar.gz (3.2MB)
#      |████████████████████████████████| 3.2MB 18.1MB/s
# Collecting cssselect>=0.9.1
#   Downloading https://files.pythonhosted.org/packages/3b/d4/3b5c17f00cce85b9a1e6f91096e1cc8e8ede2e1be8e96b87ce1ed09e92c5/cssselect-1.1.0-py2.py3-none-any.whl
# Collecting cryptography>=2.0
#   Downloading https://files.pythonhosted.org/packages/b2/26/7af637e6a7e87258b963f1731c5982fb31cd507f0d90d91836e446955d02/cryptography-3.4.7-cp36-abi3-manylinux2014_x86_64.whl (3.2MB)
#      |████████████████████████████████| 3.2MB 43.1MB/s
# Collecting Twisted[http2]>=17.9.0
#   Downloading https://files.pythonhosted.org/packages/f2/16/3eb9c66a7bfb5220c7bcbaaac33d359fe8a157b028959cd210983749b2e0/Twisted-21.2.0-py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.1MB 39.4MB/s
# Collecting itemloaders>=1.0.1
#   Downloading https://files.pythonhosted.org/packages/b3/2b/eb2ddf7becf834679273a6f79ffdc6fbedf07c5272e2eddf412582143c0e/itemloaders-1.0.4-py3-none-any.whl
# Collecting itemadapter>=0.1.0
#   Downloading https://files.pythonhosted.org/packages/88/83/ab33780fd93278e699561d61862d27343c95d3fe0a0081acd73e8e26a649/itemadapter-0.2.0-py3-none-any.whl
# Collecting h2<4.0,>=3.0
#   Downloading https://files.pythonhosted.org/packages/25/de/da019bcc539eeab02f6d45836f23858ac467f584bfec7a526ef200242afe/h2-3.2.0-py2.py3-none-any.whl (65kB)
#      |████████████████████████████████| 71kB 7.1MB/s
# Collecting PyDispatcher>=2.0.5; platform_python_implementation == "CPython"
#   Downloading https://files.pythonhosted.org/packages/cd/37/39aca520918ce1935bea9c356bcbb7ed7e52ad4e31bff9b943dfc8e7115b/PyDispatcher-2.0.5.tar.gz
# Collecting queuelib>=1.4.2
#   Downloading https://files.pythonhosted.org/packages/ee/30/0670f4b7a4eef6cf453336c5661eff41da2650e5f143c039b50e033732bd/queuelib-1.6.1-py2.py3-none-any.whl
# Collecting service-identity>=16.0.0
#   Downloading https://files.pythonhosted.org/packages/93/5a/5e93f280ec7be676b5a57f305350f439d31ced168bca04e6ffa64b575664/service_identity-21.1.0-py2.py3-none-any.whl
# Collecting pyOpenSSL>=16.2.0
#   Downloading https://files.pythonhosted.org/packages/b2/5e/06351ede29fd4899782ad335c2e02f1f862a887c20a3541f17c3fa1a3525/pyOpenSSL-20.0.1-py2.py3-none-any.whl (54kB)
#      |████████████████████████████████| 61kB 7.0MB/s
# Collecting zope.interface>=4.1.3
#   Downloading https://files.pythonhosted.org/packages/bb/a7/94e1a92c71436f934cdd2102826fa041c83dcb7d21dd0f1fb1a57f6e0620/zope.interface-5.4.0-cp37-cp37m-manylinux2010_x86_64.whl (251kB)
#      |████████████████████████████████| 256kB 47.6MB/s
# Requirement already satisfied: lxml>=3.5.0; platform_python_implementation == "CPython" in /usr/local/lib/python3.7/dist-packages (from scrapy) (4.2.6)
# Collecting parsel>=1.5.0
#   Downloading https://files.pythonhosted.org/packages/23/1e/9b39d64cbab79d4362cdd7be7f5e9623d45c4a53b3f7522cd8210df52d8e/parsel-1.6.0-py2.py3-none-any.whl
# Collecting w3lib>=1.17.0
#   Downloading https://files.pythonhosted.org/packages/a3/59/b6b14521090e7f42669cafdb84b0ab89301a42f1f1a82fcf5856661ea3a7/w3lib-1.22.0-py2.py3-none-any.whl
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from protego>=0.1.15->scrapy) (1.15.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=2.0->scrapy) (1.14.5)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from Twisted[http2]>=17.9.0->scrapy) (21.2.0)
# Collecting incremental>=16.10.1
#   Downloading https://files.pythonhosted.org/packages/99/3b/4f80dd10cb716f3a9e22ae88f026d25c47cc3fdf82c2747f3d59c98e4ff1/incremental-21.3.0-py2.py3-none-any.whl
# Collecting constantly>=15.1
#   Downloading https://files.pythonhosted.org/packages/b9/65/48c1909d0c0aeae6c10213340ce682db01b48ea900a7d9fce7a7910ff318/constantly-15.1.0-py2.py3-none-any.whl
# Collecting Automat>=0.8.0
#   Downloading https://files.pythonhosted.org/packages/dd/83/5f6f3c1a562674d65efc320257bdc0873ec53147835aeef7762fe7585273/Automat-20.2.0-py2.py3-none-any.whl
# Collecting hyperlink>=17.1.1
#   Downloading https://files.pythonhosted.org/packages/6e/aa/8caf6a0a3e62863cbb9dab27135660acba46903b703e224f14f447e57934/hyperlink-21.0.0-py2.py3-none-any.whl (74kB)
#      |████████████████████████████████| 81kB 9.5MB/s
# Collecting priority<2.0,>=1.1.0; extra == "http2"
#   Downloading https://files.pythonhosted.org/packages/de/96/2f4b8da7be255cd41e825c398efd11a6706ff86e66ae198f012204aa2a4f/priority-1.3.0-py2.py3-none-any.whl
# Collecting jmespath>=0.9.5
#   Downloading https://files.pythonhosted.org/packages/07/cb/5f001272b6faeb23c1c9e0acc04d48eaaf5c862c17709d20e3469c6e0139/jmespath-0.10.0-py2.py3-none-any.whl
# Collecting hpack<4,>=3.0
#   Downloading https://files.pythonhosted.org/packages/8a/cc/e53517f4a1e13f74776ca93271caef378dadec14d71c61c949d759d3db69/hpack-3.0.0-py2.py3-none-any.whl
# Collecting hyperframe<6,>=5.2.0
#   Downloading https://files.pythonhosted.org/packages/19/0c/bf88182bcb5dce3094e2f3e4fe20db28a9928cb7bd5b08024030e4b140db/hyperframe-5.2.0-py2.py3-none-any.whl
# Requirement already satisfied: pyasn1-modules in /usr/local/lib/python3.7/dist-packages (from service-identity>=16.0.0->scrapy) (0.2.8)
# Requirement already satisfied: pyasn1 in /usr/local/lib/python3.7/dist-packages (from service-identity>=16.0.0->scrapy) (0.4.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from zope.interface>=4.1.3->scrapy) (57.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=2.0->scrapy) (2.20)
# Requirement already satisfied: idna>=2.5 in /usr/local/lib/python3.7/dist-packages (from hyperlink>=17.1.1->Twisted[http2]>=17.9.0->scrapy) (2.10)
# Building wheels for collected packages: protego, PyDispatcher
#   Building wheel for protego (setup.py) ... done
#   Created wheel for protego: filename=Protego-0.1.16-cp37-none-any.whl size=7783 sha256=50a9f5f3a0fcf6b2bde7d72bc9caacf4608b10c515c4d3aa72c5ab5c44aeff6b
#   Stored in directory: /root/.cache/pip/wheels/51/01/d1/4a2286a976dccd025ba679acacfe37320540df0f2283ecab12
#   Building wheel for PyDispatcher (setup.py) ... done
#   Created wheel for PyDispatcher: filename=PyDispatcher-2.0.5-cp37-none-any.whl size=11517 sha256=6998606784413f3297b46bf0700ff5bd2915a242cedabe2f9807e6ef5695d629
#   Stored in directory: /root/.cache/pip/wheels/88/99/96/cfef6665f9cb1522ee6757ae5955feedf2fe25f1737f91fa7f
# Successfully built protego PyDispatcher
# Installing collected packages: protego, cssselect, cryptography, zope.interface, incremental, constantly, Automat, hyperlink, hpack, hyperframe, h2, priority, Twisted, itemadapter, jmespath, w3lib, parsel, itemloaders, PyDispatcher, queuelib, service-identity, pyOpenSSL, scrapy
# Successfully installed Automat-20.2.0 PyDispatcher-2.0.5 Twisted-21.2.0 constantly-15.1.0 cryptography-3.4.7 cssselect-1.1.0 h2-3.2.0 hpack-3.0.0 hyperframe-5.2.0 hyperlink-21.0.0 incremental-21.3.0 itemadapter-0.2.0 itemloaders-1.0.4 jmespath-0.10.0 parsel-1.6.0 priority-1.3.0 protego-0.1.16 pyOpenSSL-20.0.1 queuelib-1.6.1 scrapy-2.5.0 service-identity-21.1.0 w3lib-1.22.0 zope.interface-5.4.0

# %%
# Check if Scrapy is properly installed
# !scrapy
# Out:
# Scrapy 2.5.0 - no active project
#
# Usage:
#   scrapy <command> [options] [args]
#
# Available commands:
#   bench         Run quick benchmark test
#   commands
#   fetch         Fetch a URL using the Scrapy downloader
#   genspider     Generate new spider using pre-defined templates
#   runspider     Run a self-contained spider (without creating a project)
#   settings      Get settings values
#   shell         Interactive scraping console
#   startproject  Create new project
#   version       Print Scrapy version
#   view          Open URL in browser, as seen by Scrapy
#
#   [ more ]      More commands available when run from project directory
#
# Use "scrapy <command> -h" to see more info about a command

# %%
# Mount drive
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# create a directory for the project
# !mkdir /content/gdrive/MyDrive/scrapyExercise
# Out:
# mkdir: cannot create directory ‘/content/gdrive/MyDrive/scrapyExercise’: File exists

# %%
# Navigate to my drive
# %cd /content/gdrive/MyDrive/scrapyExercise
# Out:
# /content/gdrive/MyDrive/scrapyExercise

# %%
# Start a scrapy project and call it book_scrape
# !scrapy startproject isizulu_scrape
# Out:
# New Scrapy project 'isizulu_scrape', using template directory '/usr/local/lib/python3.7/dist-packages/scrapy/templates/project', created in:
#     /content/gdrive/MyDrive/scrapyExercise/isizulu_scrape
#
# You can start your first spider with:
#     cd isizulu_scrape
#     scrapy genspider example example.com

# %%
# Navigate to the top level project directory - book_scrape
# %cd /content/gdrive/MyDrive/scrapyExercise/isizulu_scrape
# Out:
# /content/gdrive/MyDrive/scrapyExercise/isizulu_scrape

# %%
# Invoke the crawl command on the spider(crawler) called 'books' created in 
# the Spider directory found in the last subfolder of the book_scrape project directory
# !scrapy crawl isuzulu
# Out:
# 2021-06-15 15:44:45 [scrapy.utils.log] INFO: Scrapy 2.5.0 started (bot: isizulu_scrape)
# 2021-06-15 15:44:45 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 21.2.0, Python 3.7.10 (default, May  3 2021, 02:48:31) - [GCC 7.5.0], pyOpenSSL 20.0.1 (OpenSSL 1.1.1k  25 Mar 2021), cryptography 3.4.7, Platform Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic
# 2021-06-15 15:44:45 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2021-06-15 15:44:45 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'isizulu_scrape',
#  'NEWSPIDER_MODULE': 'isizulu_scrape.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['isizulu_scrape.spiders']}
# 2021-06-15 15:44:45 [scrapy.extensions.telnet] INFO: Telnet Password: 050b16d29b05ab21
# 2021-06-15 15:44:45 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2021-06-15 15:44:45 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2021-06-15 15:44:45 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2021-06-15 15:44:45 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2021-06-15 15:44:45 [scrapy.core.engine] INFO: Spider opened
# 2021-06-15 15:44:45 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2021-06-15 15:44:45 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2021-06-15 15:44:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.isolezwe.co.za/robots.txt> (referer: None)
# 2021-06-15 15:44:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.isolezwe.co.za/> (referer: None)
# 2021-06-15 15:44:46 [scrapy.core.engine] INFO: Closing spider (finished)
# 2021-06-15 15:44:46 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 446,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 44447,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 2,
#  'elapsed_time_seconds': 0.879686,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2021, 6, 15, 15, 44, 46, 537227),
#  'httpcompression/response_bytes': 118432,
#  'httpcompression/response_count': 2,
#  'log_count/DEBUG': 2,
#  'log_count/INFO': 10,
#  'memusage/max': 88563712,
#  'memusage/startup': 88563712,
#  'response_received_count': 2,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2021, 6, 15, 15, 44, 45, 657541)}
# 2021-06-15 15:44:46 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
# view content of downloaded html file
# !cat /content/gdrive/MyDrive/scrapyExercise/isizulu_scrape/isuzulu.html
# Out:
# <!doctype html>
# <html lang="zu">
#   <head>
#       <script>window.VIDEOJS_NO_DYNAMIC_STYLE = true</script>
#       <script>
#         if ('serviceWorker' in navigator) {
#           navigator.serviceWorker.register('/sw.js')
#           .then(registration => {
#             console.log('SW registered')
#             registration.pushManager.subscribe({userVisibleOnly: true})
#           })
#         }
#       </script>
#
#       <!-- Schema Scripts -->
#       <script data-react-helmet="true" type="application/ld+json">{"@context":"https://schema.org","@graph":[{"@type":"WebPage","name":"Isolezwe | Liwela Umfula Ugcwele","alternateName":"no","url":"https://www.isolezwe.co.za","description":"Isolezwe likulethela izindaba ezishisayo, ezihlabahlosile nezingachemile zakamuva ezithinta ipolitiki, izigameko ezingajewayelekile, umphakathi jikelele, ezempilo, ezemfundo, ezemidlalo nezokungcebeleka ngolimi lwakho."},{"@type":"NewsMediaOrganization","name":"Isolezwe | Liwela Umfula Ugcwele","alternateName":"no","url":"https://www.isolezwe.co.za","logo":"https://www.isolezwe.co.za/logo.jpg","sameAs":["https://www.facebook.com/isolezwenews/","https://twitter.com/isolezwenews","https://www.instagram.com/isolezwe/"]}]}</script>
#       <!-- Meta Information -->
#       <meta data-react-helmet="true" name="msapplication-TileColor" content="#ffffff"/><meta data-react-helmet="true" name="theme-color" content="#ffffff"/><meta data-react-helmet="true" name="msvalidate.01" content="5A0910AA1A12E32A5352933CF5FD96E9"/><meta data-react-helmet="true" property="fb:app_id" content="1915095138801045"/><meta data-react-helmet="true" property="og:type" content="article"/><meta data-react-helmet="true" charset="utf-8"/><meta data-react-helmet="true" property="og:title" content="Isolezwe | Liwela Umfula Ugcwele"/><meta data-react-helmet="true" property="og:image" content="/static/media/isolezwe.4ab579eb.svg"/><meta data-react-helmet="true" itemprop="inLanguage" content="zu"/><meta data-react-helmet="true" itemprop="image" content="/static/media/isolezwe.4ab579eb.svg"/><meta data-react-helmet="true" name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/><meta data-react-helmet="true" name="mobile-web-app-capable" content="yes"/><meta data-react-helmet="true" name="theme-color" content="#ffffff"/><meta data-react-helmet="true" name="google-site-verification" content="pzAffsof8VshOp53XmZa9qZwwSMWIzKq_U8TnBj93U8"/><meta data-react-helmet="true" itemprop="image" content="/static/media/isolezwe.4ab579eb.svg"/><meta data-react-helmet="true" itemprop="thumbnailUrl" content="/static/media/isolezwe.4ab579eb.svg"/><meta data-react-helmet="true" property="og:url" content="https://www.isolezwe.co.za"/><meta data-react-helmet="true" name="description" content="Isolezwe likulethela izindaba ezishisayo, ezihlabahlosile nezingachemile zakamuva ezithinta ipolitiki, izigameko ezingajewayelekile, umphakathi jikelele, ezempilo, ezemfundo, ezemidlalo nezokungcebeleka ngolimi lwakho."/><meta data-react-helmet="true" itemprop="description" content="Isolezwe likulethela izindaba ezishisayo, ezihlabahlosile nezingachemile zakamuva ezithinta ipolitiki, izigameko ezingajewayelekile, umphakathi jikelele, ezempilo, ezemfundo, ezemidlalo nezokungcebeleka ngolimi lwakho."/><meta data-react-helmet="true" property="og:description" content="Isolezwe likulethela izindaba ezishisayo, ezihlabahlosile nezingachemile zakamuva ezithinta ipolitiki, izigameko ezingajewayelekile, umphakathi jikelele, ezempilo, ezemfundo, ezemidlalo nezokungcebeleka ngolimi lwakho."/><meta data-react-helmet="true" name="twitter:site" content="@dailyvoicesa"/><meta data-react-helmet="true" name="twitter:creator" content="IsolezweNews"/><meta data-react-helmet="true" name="twitter:description" content="Isolezwe likulethela izindaba ezishisayo, ezihlabahlosile nezingachemile zakamuva ezithinta ipolitiki, izigameko ezingajewayelekile, umphakathi jikelele, ezempilo, ezemfundo, ezemidlalo nezokungcebeleka ngolimi lwakho."/><meta data-react-helmet="true" name="twitter:title" content="Isolezwe likulethela izindaba ezishisayo, ezihlabahlosile nezingachemile zakamuva ezithinta ipolitiki, izigameko ezingajewayelekile, umphakathi jikelele, ezempilo, ezemfundo, ezemidlalo nezokungcebeleka ngolimi lwakho."/><meta data-react-helmet="true" name="twitter:card" content="summary_large_image"/><meta data-react-helmet="true" name="twitter:image:src" content="/static/media/isolezwe.4ab579eb.svg"/>
#       <!-- Title -->
#       <title data-react-helmet="true">Isolezwe | Liwela Umfula Ugcwele</title>
#       <!-- Links -->
#       <link data-react-helmet="true" rel="icon" type="image/x-icon" href="/static/media/favicon.c9a90a0b.ico"/><link data-react-helmet="true" rel="apple-touch-icon" sizes="180x180" href="data:image/png;base64,..."/><link data-react-helmet="true" rel="icon" type="image/png" sizes="32x32" href="data:image/png;base64,..."/><link data-react-helmet="true" rel="icon" type="image/png" sizes="16x16" href="data:image/png;base64,..."/><link data-react-helmet="true" rel="mask-icon" href="/static/media/safari-pinned-tab.b53191c6.svg" color="#5bbad5"/><link data-react-helmet="true" rel="canonical" itemprop="url" href="https://www.isolezwe.co.za"/>
#       <link rel="manifest" href="/manifest.json">
#
#       <!-- Google Tag Manager -->
#       <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#       'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#       })(window,document,'script','dataLayer','GTM-P6MM52X');</script>
#       <!-- End Google Tag Manager -->
#       <script type='text/javascript'>!function(f,b,e,v,n,t,s) {
#         if(f.fbq)return;n=f.fbq=function() {
#            n.callMethod? n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#         if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#         n.queue=[];t=b.createElement(e);t.async=!0;
#         t.src=v;s=b.getElementsByTagName(e)[0];
#         s.parentNode.insertBefore(t,s)}(window,document,'script','https://connect.facebook.net/en_US/fbevents.js');
#         fbq('init', '794201197427829');
#         fbq('track', 'PageView');</script>
#       <noscript><img height="1" width="1" src="https://www.facebook.com/tr?id=794201197427829&ev=PageView&noscript=1"/></noscript>
#
#       <!-- Lotame -->
#       <link rel="preconnect" href="https://tags.crwdcntrl.net">
#       <link rel="preconnect" href="https://bcp.crwdcntrl.net">
#       <link rel="dns-prefetch" href="https://tags.crwdcntrl.net">
#       <link rel="dns-prefetch" href="https://bcp.crwdcntrl.net">
#       <script>
#         ! function() {
#           var lotameClientId = '10529';
#           var lotameTagInput = {
#               data: {},
#               config: {
#                 clientId: Number(lotameClientId)
#               }
#           };
#           // Lotame initialization
#           var lotameConfig = lotameTagInput.config || {};
#           var namespace = window['lotame_' + lotameConfig.clientId] = {};
#           namespace.config = lotameConfig;
#           namespace.data = lotameTagInput.data || {};
#           namespace.cmd = namespace.cmd || [];
#         } ();
#       </script>
#       <script async src="https://tags.crwdcntrl.net/lt/c/10529/lt.min.js"></script>
#
#       <!-- Loadable Links -->
#       <link data-chunk="pages-LandingPages-HomePage" rel="preload" as="script" href="/static/js/0.89ab8413.chunk.js">
# <link data-chunk="client" rel="preload" as="style" href="/static/css/client.bd430b41.chunk.css">
# <link data-chunk="pages-LandingPages-HomePage" rel="preload" as="style" href="/static/css/0.89ab8413.chunk.css">
# <link data-chunk="client" rel="preload" as="style" href="/static/css/11.4d30f4c8.chunk.css">
# <link data-chunk="pages-LandingPages-HomePage" rel="preload" as="style" href="/static/css/2.d645bd88.chunk.css">
# <link data-chunk="pages-LandingPages-HomePage" rel="preload" as="style" href="/static/css/7.116388b7.chunk.css">
# <link data-chunk="client" rel="preload" as="script" href="/static/js/runtime~client.837cc58b.js">
# <link data-chunk="client" rel="preload" as="script" href="/static/js/client.bd430b41.chunk.js">
# <link data-chunk="pages-LandingPages-HomePage" rel="preload" as="script" href="/static/js/2.d645bd88.chunk.js">
# <link data-chunk="client" rel="preload" as="script" href="/static/js/11.4d30f4c8.chunk.js">
# <link data-chunk="pages-LandingPages-HomePage" rel="preload" as="script" href="/static/js/7.116388b7.chunk.js">
# <link data-chunk="pages-LandingPages-HomePage" rel="preload" as="script" href="/static/js/1.f91add8a.chunk.js">
# <link data-chunk="pages-LandingPages-HomePage" rel="preload" as="script" href="/static/js/pages-Feedback.d6a3ef7c.chunk.js">
#
#       <!-- Loadable Styles -->
#       <link data-chunk="client" rel="stylesheet" href="/static/css/11.4d30f4c8.chunk.css">
# <link data-chunk="client" rel="stylesheet" href="/static/css/client.bd430b41.chunk.css">
# <link data-chunk="pages-LandingPages-HomePage" rel="stylesheet" href="/static/css/0.89ab8413.chunk.css">
# <link data-chunk="pages-LandingPages-HomePage" rel="stylesheet" href="/static/css/2.d645bd88.chunk.css">
# <link data-chunk="pages-LandingPages-HomePage" rel="stylesheet" href="/static/css/7.116388b7.chunk.css">
#       <style data-styled="" data-styled-version="4.4.1">
# /* sc-component-id: sc-global-2782782138 */
# html{box-sizing:border-box;} *,*::before,*::after{box-sizing:inherit;} :root{-moz-tab-size:4;tab-size:4;} html{line-height:1.15;-webkit-text-size-adjust:100%;} body{margin:0;} body{font-family:-apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,Helvetica,Arial,sans-serif,"Apple Color Emoji","Segoe UI Emoji","Segoe UI Symbol";} hr{height:0;} abbr[title]{-webkit-text-decoration:underline dotted;text-decoration:underline dotted;} b,strong{font-weight:bolder;} code,kbd,samp,pre{font-family:SFMono-Regular,Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:1em;} small{font-size:80%;} sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline;} sub{bottom:-0.25em;} sup{top:-0.5em;} button,input,optgroup,select,textarea{font-family:inherit;font-size:100%;line-height:1.15;margin:0;} button,select{text-transform:none;} button,[type="button"],[type="reset"],[type="submit"]{-webkit-appearance:button;} button::-moz-focus-inner,[type="button"]::-moz-focus-inner,[type="reset"]::-moz-focus-inner,[type="submit"]::-moz-focus-inner{border-style:none;padding:0;} button:-moz-focusring,[type="button"]:-moz-focusring,[type="reset"]:-moz-focusring,[type="submit"]:-moz-focusring{outline:1px dotted ButtonText;} fieldset{padding:0.35em 0.75em 0.625em;} legend{padding:0;} progress{vertical-align:baseline;} [type="number"]::-webkit-inner-spin-button,[type="number"]::-webkit-outer-spin-button{height:auto;} [type="search"]{-webkit-appearance:textfield;outline-offset:-2px;} [type="search"]::-webkit-search-decoration{-webkit-appearance:none;} ::-webkit-file-upload-button{-webkit-appearance:button;font:inherit;} summary{display:list-item;} *,*::before,*::after{-webkit-box-sizing:border-box;-moz-box-sizing:border-box;box-sizing:border-box;-webkit-font-smoothing:subpixel-antialiased;} ::-webkit-input-placeholder{color:$grey;} ::-moz-placeholder{color:$grey;} :-ms-input-placeholder{color:$grey;} :-moz-placeholder{color:$grey;}</style>
#   </head>
#   <body class="menu-closed">
#     <!-- Google Tag Manager (noscript) -->
#     <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-P6MM52X"
#     height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
#     <!-- End Google Tag Manager (noscript) -->
#     <div id="fb-root"></div>
#     <script>
#       (function(d, s, id) {
#         var js, fjs = d.getElementsByTagName(s)[0];
#               if (d.getElementById(id)) return;
#               js = d.createElement(s); js.id = id;
#               js.src = "https://connect.facebook.net/en_US/sdk.js#xfbml=1&version=v2.6";
#               fjs.parentNode.insertBefore(js, fjs);
#       }(document, 'script', 'facebook-jssdk'));
#     </script>
#     <div id="root"><div class="app"><div class="ui segment pushable"><div class="ui vertical labeled icon ui push left wide sidebar menu"></div><div class="pusher"><header role="banner"><a href="#main-content" class="show-on-focus">Skip to content</a><div class="wrapper"><nav class="commercial-nav"><ul><li><a rel="noopener noreferrer" href="https://www.iol.co.za" target="_blank" title="IOL" id="iol-commerical-nav">IOL</a></li><li><a rel="noopener noreferrer" href="http://www.loot.co.za" target="_blank" title="Loot" id="young-independent-commerical-nav">Shop @ Loot</a></li><li><a href="https://www.stylemode.co.za" title="StyleMode" target="_blank" rel="noopener noreferrer nofollow">StyleMode</a></li><li><a rel="noopener noreferrer" href="http://www.property360.co.za?referrer=isol" target="_blank" title="Property360" id="iol-property-commerical-nav">Property360</a></li><li><a rel="noopener noreferrer" href="https://www.voices360.co.za" target="_blank" title="Voices360" id="voices360-commerical-nav">Voices360</a></li><li><a rel="noopener noreferrer" href="https://www.iol.co.za/pressoffice" target="_blank" title="Press Office" id="pressoffice-commerical-nav">Press Office</a></li><li><a rel="noopener noreferrer" href="https://blog.talent360.co.za/" target="_blank" title="Talent360" id="talent360-commerical-nav">Talent360</a></li></ul><div>Tue, Jun 15</div></nav></div><div class="border-bottom"><div class="wrapper"><a class="logo" href="/"><img src="/static/media/isolezwe.4ab579eb.svg" alt="Isolezwe"/></a></div></div><div class="wrapper"><nav><ul><li><a href="/">Home</a></li><li><a href="/izindaba">Izindaba</a></li><li><a href="/ezokungcebeleka">Ezokungcebeleka</a><ul class="menu-articles"><li><a href="/ezokungcebeleka/ezemisakazo">Ezemisakazo</a></li><li><a href="/ezokungcebeleka/ezethelevishini">Ezethelevishini</a></li><li><a href="/ezokungcebeleka/osaziwayo">Osaziwayo</a></li><li><a href="/ezokungcebeleka/umculo">Umculo</a></li></ul></li><li><a href="/ezemidlalo">Ezemidlalo</a><ul class="menu-articles"><li><a href="/ezemidlalo/ibhola">Ibhola</a><ul class="sub-mnu-nav"><li><a href="/ezemidlalo/ibhola/upotshoza">Upotshoza</a></li></ul></li><li><a href="/ezemidlalo/isigcawu-sabalandeli">Isigcawu Sabalandeli</a></li><li><a href="/ezemidlalo/ezinye-ezemidlalo">Ezinye Ezemidlalo</a></li></ul></li><li><a href="/imibono">Imibono</a></li><li><a href="/intandokazi">Intandokazi</a><ul class="menu-articles"><li><a href="/intandokazi/ezemfashini-nezokuzicwala">Ezemfashini Nezokuzicwala</a></li><li><a href="/intandokazi/imbokodo">Imbokodo</a></li></ul></li><li><a href="/impilo-yabantu">Impilo Yabantu</a><ul class="menu-articles"><li><a href="/impilo-yabantu/ezothando">Ezothando</a></li><li><a href="/impilo-yabantu/ezempilo">Ezempilo</a></li><li><a href="/impilo-yabantu/ezezimoto">Ezezimoto</a></li></ul></li><li class="search-btn"><a href="/"><svg xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path fill="#FFFFFF" d="M1413.15266,71.0943396 L1412.06861,71.0943396 L1411.68439,70.7238422 C1413.02916,69.1595197 1413.83877,67.1286449 1413.83877,64.9193825 C1413.83877,59.9931389 1409.84563,56 1404.91938,56 C1399.99314,56 1396,59.9931389 1396,64.9193825 C1396,69.8456261 1399.99314,73.838765 1404.91938,73.838765 C1407.12864,73.838765 1409.15952,73.0291595 1410.72384,71.6843911 L1411.09434,72.0686106 L1411.09434,73.1526587 L1417.9554,80 L1420,77.9554031 L1413.15266,71.0943396 Z M1404.91938,71.0943396 C1401.50257,71.0943396 1398.74443,68.3361921 1398.74443,64.9193825 C1398.74443,61.5025729 1401.50257,58.7444254 1404.91938,58.7444254 C1408.33619,58.7444254 1411.09434,61.5025729 1411.09434,64.9193825 C1411.09434,68.3361921 1408.33619,71.0943396 1404.91938,71.0943396 Z" transform="translate(-1396 -56)"></path></svg></a></li></ul></nav></div></header><div class="wing-banners"><div class="advert-wingbanner-left"><div style="width:160px;height:600px"></div></div><div class="advert-wingbanner-right"><div style="width:160px;height: ...
#     <script type="text/javascript">window.__PRELOADED_STATE__ = {"article":{"lastFetch":0,"didInvalidate":false,"isFetching":false,"hasFetched":false,"hasError":false,"is404":false,"checkCanonical":false,"canonical":null,"error":null,"article":null,"previewArticle":false,"readNext":[],"readArticles":[]},"articles":{"tvbox":{"hasFetched":true,"isFetching":false,"didInvalidate":false,"articles":[{"contentKey":"1e404a3d-2a69-4c80-ae39-b206b251afe9","uuid":"1e404a3d-2a69-4c80-ae39-b206b251afe9","headline":"Isihluku kubulawa intombazane ena-14 eHammarsdale","teaserHeadline":null,"abstract":null,"published":"2021-06-10T12:16:00Z","modified":"2021-06-10T12:16:52Z","section":"izindaba","sectionLabel":"Izindaba","titleKey":"no","secondaryTags":[],"author":"Gcwalisile Khanyile","image":{"id":"im:\u002F\u002Fimage\u002Fk5CmU5rzsxaxkBQvHkVmkk1RbOo.jpg","url":"https:\u002F\u002Fxlibris.public.prod.oc.inl.infomaker.io:8443\u002Fopencontent\u002Fobjects\u002Fae89ab19-5912-5fe6-8bfd-f7459f50caff","caption":"ToBeConfirmed","width":"1700","height":"1126","crop":{"x":0,"y":60,"w":1700,"h":958}},"wordCount":"ToBeConfirmed","displayTag":{"slug":"izindaba","label":"Izindaba"}},{"contentKey":"c9d9631b-a152-413e-b441-0e368dadf9b0","uuid":"c9d9631b-a152-413e-b441-0e368dadf9b0","headline":"Kuqhume inganono erenki kubulawa usomatekisi","teaserHeadline":null,"abstract":null,"published":"2021-06-10T13:11:00Z","modified":"2021-06-10T13:11:32Z","section":"izindaba","sectionLabel":"Izindaba","titleKey":"no","secondaryTags":[],"author":"Nontuthuko Ngubane","image":{"id":"im:\u002F\u002Fimage\u002F02LesJeN87i6uzcu9LneZMAO2Rs.jpg","url":"https:\u002F\u002Fxlibris.public.prod.oc.inl.infomaker.io:8443\u002Fopencontent\u002Fobjects\u002F346945f5-b292-53d4-ae70-5b70ddf0e1f1","caption":"ToBeConfirmed","width":"768","height":"1024","crop":{"x":0,"y":330,"w":768,"h":432}},"wordCount":"ToBeConfirmed","displayTag":{"slug":"izindaba","label":"Izindaba"}},{"contentKey":"3e3ba7ba-f8a0-43d8-b024-92b05ed1adff","uuid":"3e3ba7ba-f8a0-43d8-b024-92b05ed1adff","headline":"ISilo esibusayo masihlonishwe njengoyise","teaserHeadline":null,"abstract":null,"published":"2021-06-10T18:50:00Z","modified":"2021-06-10T18:50:29Z","section":"imibono","sectionLabel":"Imibono","titleKey":"no","secondaryTags":[],"image":{"id":"im:\u002F\u002Fimage\u002FVbqpHmNBcIds6xYZI9gHgBaKfHc.jpg","url":"https:\u002F\u002Fxlibris.public.prod.oc.inl.infomaker.io:8443\u002Fopencontent\u002Fobjects\u002F49e5fa3e-f2d2-5482-b57f-34759be6621d","caption":"ToBeConfirmed","width":"3552","height":"2368"},"wordCount":"ToBeConfirmed","displayTag":{"slug":"imibono","label":"Imibono"}},{"contentKey":"e7595086-d517-46cf-8e22-58f82ef1f564","uuid":"e7595086-d517-46cf-8e22-58f82ef1f564","headline":"Udide odokotela                   ezala-10 wezingane","teaserHeadline":null,"abstract":null,"published":"2021-06-09T14:03:00Z","modified":"2021-06-09T14:03:55Z","section":"izindaba","sectionLabel":"Izindaba","titleKey":"no","secondaryTags":[],"author":"Nontuthuko Ngubane","image":{"id":"im:\u002F\u002Fimage\u002FaZ58dMgQa2tt7jXocz6yBtSqu3w.jpg","url":"https:\u002F\u002Fxlibris.public.prod.oc.inl.infomaker.io:8443\u002Fopencontent\u002Fobjects\u002F43aff584-fc4a-595e-8cf1-5d237713d2a0","caption":"ToBeConfirmed","width":"2126","height":"1494","crop":{"x":0,"y":0,"w":2126,"h":1196}},"wordCount":"ToBeConfirmed","displayTag":{"slug":"izindaba","label":"Izindaba"}},{"contentKey":"1144f8bd-bc8b-4fcb-8db0-7a8eb66bab3d","uuid":"1144f8bd-bc8b-4fcb-8db0-7a8eb66bab3d","headline":"Udutshulwe washona egoloza ukuqhela emotweni yemali","teaserHeadline":null,"abstract":null,"published":"2021-06-09T14:19:00Z","modified":"2021-06-09T14:19:15Z","section":"izindaba","sectionLabel":"Izindaba","titleKey":"no","secondaryTags":[],"author":"Khulekani Maseko","image":{"id":"im:\u002F\u002Fimage\u002Frw9I1fH_lIQ-k7QwLDHl2QYsBrg.jpg","url":"https:\u002F\u002Fxlibris.public.prod.oc.inl.infomaker.io:8443\u002Fopencontent\u002Fobjects\u002F45bf3367-12c7-551e-ab02 ...
#     <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">[0,2,7,1,5]</script><script id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">{"namedChunks":["pages-LandingPages-HomePage"]}</script>
# <script async data-chunk="client" src="/static/js/runtime~client.837cc58b.js"></script>
# <script async data-chunk="client" src="/static/js/11.4d30f4c8.chunk.js"></script>
# <script async data-chunk="client" src="/static/js/client.bd430b41.chunk.js"></script>
# <script async data-chunk="pages-LandingPages-HomePage" src="/static/js/0.89ab8413.chunk.js"></script>
# <script async data-chunk="pages-LandingPages-HomePage" src="/static/js/2.d645bd88.chunk.js"></script>
# <script async data-chunk="pages-LandingPages-HomePage" src="/static/js/7.116388b7.chunk.js"></script>
# <script async data-chunk="pages-LandingPages-HomePage" src="/static/js/1.f91add8a.chunk.js"></script>
# <script async data-chunk="pages-LandingPages-HomePage" src="/static/js/pages-Feedback.d6a3ef7c.chunk.js"></script>
#     <script type="text/javascript">
#       (function(t,r,a,c,k,n,o,w){t['em_ns']=k;w=1*new Date();t[k]=t[k]||function(){
#         (t[k].q=t[k].q||[]).push(arguments)},t[k].t=w;n=r.createElement(a);n.async=1;
#         n.src=c+'/tag'+(t.addEventListener&&'.'||'_.')+'js?'+parseInt(w/1e9, 10);
#         o=r.getElementsByTagName(a)[0];o.parentNode.insertBefore(n,o)
#       })(window,document,'script','https://t.effectivemeasure.net','_em');
#     </script>
#     <noscript>
#       <img src="https://collector.effectivemeasure.net/noscript" alt="" style="position:absolute; left:-5px;" />
#     </noscript>
#     <!-- VICINITY LOCATION TAG BEGIN -->
#       <script async="async" src="https://static.vic-m.co/ads/vicinity-head-tag-v1.js?zoneId=2309"></script>
#     <!-- VICINITY LOCATION TAG END -->
#
#     <!-- Outbrain -->
#     <script type="text/javascript" async="async" src="https://widgets.outbrain.com/outbrain.js"></script>
#
#   </body>
# </html>

# %% [markdown]
# # The End
